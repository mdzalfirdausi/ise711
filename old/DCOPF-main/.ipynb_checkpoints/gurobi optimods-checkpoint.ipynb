# %%
from gurobi_optimods import opf
mat_file = 'power_system_test_cases\\pglib_opf_case3_lmbd.mat'
case = opf.read_case_matpower(mat_file)
result = opf.solve_opf(case, opftype="DC")
# Out:
# Set parameter OptimalityTol to value 0.0001
# Building case data structures from dictionary.
# Buses.
#     Bus 1 ID 1 is the reference bus.
#     sumloadPd 315.0 numPload 3
#     sumloadQd 130.0
#     3 buses
# Branches.
#     Numbranches: 3 active: 3
# Generators.
#     Number of generators: 3
#     Number of buses with gens: 3
#     summaxPg 4000 summaxQg 3000
# Generator cost vectors.
# Running DCOPF formulation.
# DCOPF model constructed (0.00s).
# Statistics for model 'DC_Formulation_Model':
#   Problem type                : QP
#   Linear constraint matrix    : 10 rows, 14 columns, 27 nonzeros
#   Variable types              : 14 continuous, 0 integer (0 binary)
#   Matrix range                : [1e+00, 5e+02]
#   Objective range             : [1e+00, 1e+00]
#   QObjective range            : [2e+03, 2e+03]
#   Bounds range                : [5e-01, 9e+01]
#   RHS range                   : [9e-01, 1e+00]
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1255U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Non-default parameters:
# OptimalityTol  0.0001
#
# Optimize a model with 10 rows, 14 columns and 27 nonzeros
# Model fingerprint: 0xd345fa3c
# Model has 2 quadratic objective terms
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   QObjective range [2e+03, 2e+03]
#   Bounds range     [5e-01, 9e+01]
#   RHS range        [9e-01, 1e+00]
# Presolve removed 6 rows and 8 columns
# Presolve time: 0.02s
# Presolved: 4 rows, 6 columns, 12 nonzeros
# Presolved model has 2 quadratic objective terms
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.000e+00
#  Factor NZ  : 1.000e+01
#  Factor Ops : 3.000e+01 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.89485445e+08 -5.42970784e+08  2.00e+03 2.35e+02  7.96e+05     0s
#    1   1.82780902e+06 -5.72008901e+07  7.58e+01 8.91e+00  3.44e+04     0s
#    2   1.17400363e+04 -3.46159516e+07  7.58e-05 8.91e-06  2.82e+03     0s
#    3   1.17314938e+04 -1.53308258e+05  2.86e-07 3.36e-08  1.34e+01     0s
#    4   5.69859408e+03 -3.66815318e+04  5.48e-09 6.44e-10  3.45e+00     0s
#    5   5.69733791e+03  5.65111568e+03  3.91e-14 3.77e-15  3.76e-03     0s
#    6   5.69381107e+03  5.69376053e+03  3.77e-13 7.25e-17  4.11e-06     0s
#    7   5.69380334e+03  5.69380329e+03  4.77e-13 3.74e-16  4.11e-09     0s
#
# Barrier solved model in 7 iterations and 0.05 seconds (0.00 work units)
# Optimal objective 5.69380334e+03
#
# Objective value = 5693.803341072556.
# Solution quality statistics for model 'DC_Formulation_Model' :
#   Maximum violation (unscaled/scaled):
#     Bound           : 0.00000000e+00 / 0.00000000e+00
#     Constraint      : 4.76008122e-13 / 4.76008122e-13 (Pdef_1_1_3)
#     Dual            : 0.00000000e+00 / 0.00000000e+00
#     Complementarity : 1.34697961e-05
