# %%
from gurobi_optimods import opf
mat_file = 'power_system_test_cases\\pglib_opf_case1951_rte.mat'
case = opf.read_case_matpower(mat_file)
result = opf.solve_opf(case, opftype="DC")
# Out:
# Set parameter OptimalityTol to value 0.0001
# Building case data structures from dictionary.
# Buses.
#     Bus 1278 ID 1320 is the reference bus.
#     sumloadPd 80656.5 numPload 940
#     sumloadQd 17680.19999999996
#     1951 buses
# Branches.
#     Numbranches: 2596 active: 2596
# Generators.
#     Number of generators: 391
#     Number of buses with gens: 377
#     summaxPg 98423.33000000003 summaxQg 47678.67000000003
# Generator cost vectors.
# Running DCOPF formulation.
# DCOPF model constructed (0.16s).
# Statistics for model 'DC_Formulation_Model':
#   Problem type                : LP
#   Linear constraint matrix    : 6499 rows, 6891 columns, 17664 nonzeros
#   Variable types              : 6891 continuous, 0 integer (0 binary)
#   Matrix range                : [1e+00, 2e+04]
#   Objective range             : [1e+00, 1e+00]
#   Bounds range                : [1e-03, 3e+03]
#   RHS range                   : [1e-03, 5e+02]
# ...

# %%
result['et']
# Out:
# 20.48199987411499
