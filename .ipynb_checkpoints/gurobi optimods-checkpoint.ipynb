# %%
# !pip install pyscipopt

# %%
import pyscipopt as pso
from pyscipopt import Model

# Model
model = Model("prod")
# Create decision variables
x1 = model.addVar(name="x1", vtype="C", lb=0.0, ub=None, obj=5.0, pricedVar = False)
x2 = model.addVar("x2", "C", 0, None, 6) # arguments by position
x3 = model.addVar(name="x3") # arguments by deafult: lb=0.0, ub=None, obj=0.
x4 = model.addVar(name="x4", vtype="C", lb=0.0, ub=None, obj=0.0)
x5 = model.addVar(name="x5", vtype="C", lb=0.0, ub=None, obj=0.0)
x6 = model.addVar(name="x6", vtype="C", lb=0.0, ub=None, obj=0.0)

# The objective is to maximize (the default)
# Unecessary if we had written the obj coefficient for all vars above
model.setObjective(5.0*x1 + 6.0*x2 + 8.0*x3, "maximize")
# Add constraints to the model
model.addCons(6.0*x1 + 5.0*x2 + 10.0*x3 + x4== 60.0, "c1")
model.addCons(8.0*x1 + 4.0*x2 + 4.0*x3 + x5== 40.0, "c2")
model.addCons(4.0*x1 + 5.0*x2 + 6.0*x3 + x6== 50.0, "c3")
# Out:
# c3

# %%
# Let’s deactivate presolving and heuristic solutions
model.setPresolve(pso.SCIP_PARAMSETTING.OFF)
model.setHeuristics(pso.SCIP_PARAMSETTING.OFF)
model.disablePropagation()
# let’s use the primal simplex
model.setCharParam("lp/initalgorithm","p")

# %%
# Solve
model.optimize()
# Let’s print the solution
if model.getStatus() == "optimal":
    print("Optimal value:", model.getObjVal())
    
    for v in model.getVars():
        print(v.name, " = ", model.getVal(v))
else:
    print("Problem could not be solved to optimality")
# Out:
# Optimal value: 62.0
# x1  =  0.0
# x2  =  7.000000000000001
# x3  =  2.4999999999999987
# x4  =  0.0
# x5  =  2.0000000000000018
# x6  =  0.0

# %%
x2.isInLP()
# Out:
# False

# %%
for v in model.getVars():
    print(v.name, v.isInLP())
# Out:
# x1 False
# x2 False
# x3 False
# x4 False
# x5 False
# x6 False

# %%
# Let’s print the dual variables
for c in model.getConss():
    print(c.name, model.getSlack(c), model.getDualsolLinear(c))
# Out:
# c1 -7.105427357601002e-15 -0.1999999999999998
# c2 0.0 -0.0
# c3 0.0 -1.0000000000000002

# %%
# Write the set of SCIP parameters and their settings.
model.writeParams("param.set")
# Write the instantiated model to a file
model.writeProblem("prod1_scip.lp") # lp format
model.writeProblem("prod1_scip.cip") # cip format
# Out:
# wrote parameter settings to file C:\Users\Syed\Dropbox\cAdv\Mohammed AlFirdausi\param.set
# wrote problem to file C:\Users\Syed\Dropbox\cAdv\Mohammed AlFirdausi\prod1_scip.lp
# wrote problem to file C:\Users\Syed\Dropbox\cAdv\Mohammed AlFirdausi\prod1_scip.cip
